# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# top 1 in the week of October 21, 2021
["Adele", "Easy on Me", ]
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
tracks_df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
# check for null values
pd.isnull(tracks_df).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
# check for nans
pd.isna(tracks_df).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
# convert duration of song from ms to seconds
tracks_df["duration"] = tracks_df["duration_ms"].apply(lambda x: round(x/1000))
tracks_df.drop("duration_ms", inplace=True, axis=1)
tracks_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
# ...

# %%
# NaN names
name_na = tracks_df[tracks_df["name"].isna()].index
name_na
# Out:
# Index([226336, 510975, 510976, 510978, 510979, 510982, 510983, 510984, 510986,
#        510987, 510989, 510991, 510992, 510998, 511001, 511002, 511004, 511005,
#        511010, 511063, 511070, 511073, 511074, 511083, 511085, 511088, 511093,
#        511095, 511102, 511103, 511104, 511109, 512243, 513070, 513153, 513167,
#        513173, 513229, 513231, 513293, 513369, 513379, 513395, 513396, 513473,
#        513545, 513568, 513607, 513630, 513654, 513672, 513783, 514057, 514464,
#        514468, 514476, 514492, 514499, 514541, 514760, 516861, 517163, 517176,
#        517184, 517185, 517191, 517206, 517215, 520127, 525238, 525265],
#       dtype='int64')

# %%
no_nans = tracks_df.dropna(subset=["name"])
no_nans.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
# ...

# %%
# week of 15-October 2021 -> top song in AMS is Easy on Me
no_nans[no_nans["name"].str.contains("Easy on Me", case=False)]
# Out:
#                             id                             name  popularity  \
# 55299   5p0Et9J14mQUaqZsNiFlsY  Take It Easy On Me - Remastered          39
# 63900   7C2PSApP1jxFFpPgggCAaG               Make It Easy On Me          50
# 573394  2vBX4fQwfPPRtPuj6echbt               Make It Easy on Me          30
#
#         explicit                artists                  id_artists  \
# 55299          0  ['Little River Band']  ['6clbbhnIqpHnqxwtOWcilg']
# 63900          0              ['Sybil']  ['1EbIfIjVcauDatNO4vagL1']
# 573394         0              ['Steps']  ['17UkABEasVRlCcIFZ3wHb7']
#
#        release_date  danceability  energy  key  loudness  mode  speechiness  \
# 55299          1981         0.424   0.575    9    -9.269     1       0.0330
# 63900          1990         0.676   0.549    5   -12.357     1       0.0585
# 573394   1999-10-25         0.804   0.624   11    -9.148     1       0.0251
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
adele_list = no_nans[no_nans["artists"].str.contains("Adele", case=False)].name
for i in adele_list:
    print(i)
# Out:
# Der Rosenkavalier, Op. 59, TrV 227: Hab mir's gelobt
# Die Fledermaus (short version): Part 4
# Die Fledermaus (short version): Part 2
# Die Fledermaus (short version): Part 7
# Die Fledermaus (short version): Part 9
# Fidelio, Op. 72: O wär' ich schon mit dir vereint
# Der Rosenkavalier, Op. 59, TrV 227: Ist ein Traum, kann nicht wirklich sein
# Die Fledermaus (short version): Part 1
# Die Zauberflöte, K. 620: Hm! hm! hm! hm!
# Ariadne auf Naxos, TrV 228: Zerbinetta's Scene
# You're Laughing At Me
# Slumming On Park Avenue (Finale)
# Gruber: Silent Night
# (Getting Some) Fun out of Life
# La Vie En Rose
# Dance Me To The End Of Love
# Don't Wait Too Long
# Make You Feel My Love
# Chasing Pavements
# Chasing Pavements - Live at Hotel Cafe
# Hometown Glory
# Daydreamer
# To Love You All Over Again
# Someone Like You
# Rolling in the Deep
# Set Fire to the Rain
# Turning Tables
# Rumour Has It
# Don't You Remember
# One And Only
# Skyfall
# Hope Remains - 4 Seas Breakdown
# ...
